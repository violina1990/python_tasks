# %% [markdown]
# # Intro

# %%
1+1
# Out:
# 2

# %%
print('Hello world')
# Out:
# Hello world

# %% [markdown]
# ## Subsection title

# %%
var_a = 10

# %%
var_a += 1

# %%
print(var_a)
# Out:
# 11

# %%
import pandas as pd

data = {
     'col1': [1, 2, 3, 4, 5],
     'col2': ['A', 'B', 'C', 'D', 'E'],
     'col3': [10.1, 11.2, 12.3, 13.4, 14.5]
}
df_test = pd.DataFrame(data)
display(df_test.head())
# Out:
#    col1 col2  col3
# 0     1    A  10.1
# 1     2    B  11.2
# 2     3    C  12.3
# 3     4    D  13.4
# 4     5    E  14.5

# %%
df = pd.read_csv('sample_data/california_housing_train.csv')
display(df.head())
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
'/content/sample_data/california_housing_train.csv'

# %% [markdown]
# Обрали один із пропонованих датасетів та пропонований до нього Code snippet. Запустили - запустився:

# %%
import kagglehub
path = kagglehub.dataset_download("heesoo37/120-years-of-olympic-history-athletes-and-results")
# Out:
# Using Colab cache for faster access to the '120-years-of-olympic-history-athletes-and-results' dataset.

# %% [markdown]
# Дивимось шлях:

# %%
path
# Out:
# '/kaggle/input/120-years-of-olympic-history-athletes-and-results'

# %% [markdown]
# Дивимось, які там є файли !ls (list)
# Бачимо, що є файли athlete_events.csv  noc_regions.csv:

# %%
# !ls /kaggle/input/120-years-of-olympic-history-athletes-and-results
# Out:
# athlete_events.csv  noc_regions.csv

# %%
df = pd.read_csv(
    "/kaggle/input/120-years-of-olympic-history-athletes-and-results/athlete_events.csv"
)

display(df.head())
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %% [markdown]
# Побудуємо гістограму віку людей, які тут представлені:

# %%
df.Age.hist()
# Out:
# <Axes: >

# %% [markdown]
# # Comments cection
#
# Analytics insight
